# %%
import random

def GuessNumber():
    print("Devnier un nombre entre 1 et 10\n")
    number = random.randrange(1,10)
    isContinue = "oui"
    nbrTentative = 0
    
    while(True):
        nbrTentative += 1
        reponse = input("Entrer votre réponse : ")
        
        if not reponse.isnumeric():
            print("La réponse doit être un chiffre.\n")
            continue
        else:
            reponse = int(reponse)

            if reponse > number:
                print("Faux, le nombre est inférieur à ", reponse)

            elif reponse < number:
                print("Faux, le nombre est supérieur à ", reponse)
            else:
                print("Félicitation vous avez trouvé la bonne réponse après ", nbrTentative, " tentative")
                isContinue = input("Voulez vous encore jouer ? 'oui' pour continuer : ")
                number = random.randrange(1,10)
                nbrTentative = 0
                
                if isContinue.lower() == "oui":
                    continue
                else:
                    break
            
GuessNumber()
# Out:
# Devnier un nombre entre 1 et 10
#
# Entrer votre réponse : 1
# Faux, le nombre est supérieur à  1
# Entrer votre réponse : 10
# Faux, le nombre est inférieur à  10
# Entrer votre réponse : 9
# Faux, le nombre est inférieur à  9
# Entrer votre réponse : 8
# Faux, le nombre est inférieur à  8
# Entrer votre réponse : 7
# Faux, le nombre est inférieur à  7
# Entrer votre réponse : 6
# Faux, le nombre est inférieur à  6
# Entrer votre réponse : 5
# Faux, le nombre est inférieur à  5
# Entrer votre réponse : 4
# Faux, le nombre est inférieur à  4
# Entrer votre réponse : 3
# Félicitation vous avez trouvé la bonne réponse après  9  tentative
# Voulez vous encore jouer ? 'oui' pour continuer : oui
# Entrer votre réponse : 1
# Faux, le nombre est supérieur à  1
# Entrer votre réponse : 3
# Faux, le nombre est supérieur à  3
# Entrer votre réponse : 4
# Faux, le nombre est supérieur à  4
# Entrer votre réponse : 7
# Félicitation vous avez trouvé la bonne réponse après  4  tentative
# ...

# %%
def estNbrPremier():
    print("Savoir si un nombre est premier.\n")
            
    isContinue = "oui"
    
    while(True):
        reponse = input("Entrer votre nombre à tester : ")

        if not reponse.isnumeric():
            print("La réponse doit être un chiffre.\n")
            continue
        else:
            reponse = int(reponse)

            if reponse < 2:
                print("Le nombre doit être supérieur ou égal à 2.\n")
                continue
            else:
                if reponse % 2 == 0:
                    print(reponse, " n'est pas un nombre premier\n")
                    isContinue = input("Voulez vous encore tester un nombre ? 'non' pour quitter : ")
                    if isContinue.lower() == "non":
                        break
                    else:
                        continue

                for nbr in range(2, reponse // 2):
                    if reponse % nbr == 0:
                        print(reponse, " n'est pas un nombre premier\n")
                        isContinue = input("Voulez vous encore tester un nombre ? 'non' pour quitter : ")
                        if isContinue.lower() == "non":
                            break
                        else:
                            continue
                print(reponse, " est un nombre premier\n")
                isContinue = input("Voulez vous encore tester un nombre ? 'non' pour quitter : ")
                if isContinue.lower() == "non":
                    break
                else:
                    continue
estNbrPremier()
# Out:
# Savoir si un nombre est premier.
#
# Entrer votre nombre à tester : 1
# Le nombre doit être supérieur ou égal à 2.
#
# Entrer votre nombre à tester : 2
# 2  n'est pas un nombre premier
#
# Voulez vous encore tester un nombre ? 'non' pour quitter :
# Entrer votre nombre à tester : 3
# 3  est un nombre premier
#
# Voulez vous encore tester un nombre ? 'non' pour quitter : 4
# Entrer votre nombre à tester : 4
# 4  n'est pas un nombre premier
#
# Voulez vous encore tester un nombre ? 'non' pour quitter : 5
# Entrer votre nombre à tester : 5
# 5  est un nombre premier
#
# Voulez vous encore tester un nombre ? 'non' pour quitter :
# Entrer votre nombre à tester : 6
# 6  n'est pas un nombre premier
#
# Voulez vous encore tester un nombre ? 'non' pour quitter :
# Entrer votre nombre à tester : 7
# 7  est un nombre premier
#
# Voulez vous encore tester un nombre ? 'non' pour quitter :
# Entrer votre nombre à tester : 15
# 15  n'est pas un nombre premier
#
# ...
